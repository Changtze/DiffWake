# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

plt.style.use('default')

# %%
a = np.load(rf"E:\Aeronautics\fyp\DiffWake\data\horn\weather_data.npz", allow_pickle=True)
a
# Out:
# NpzFile 'E:\\Aeronautics\\fyp\\DiffWake\\data\\horn\\weather_data.npz' with keys: wind_speed, wind_direction, weight, windrose

# %%
ws = a['wind_speed']
wd = a['wind_direction']
w = a['weight']
wr = a['windrose']

# %%
wr
# Out:
# array({'wd': array([ 22.5,  67.5, 112.5, 157.5, 202.5, 247.5, 292.5, 337.5]), 'ws': array([ 4.22222222,  6.66666667,  9.11111111, 11.55555556, 14.        ,
#        16.44444444, 18.88888889, 21.33333333, 23.77777778]), 'freq': array([[1.46852392e-02, 2.86146205e-02, 2.08400821e-02, 3.50574092e-02,
#         2.58791347e-02, 1.47932189e-02, 4.78710003e-03, 9.71817298e-04,
#         3.23939099e-04],
#        [2.59151280e-02, 2.53032430e-02, 2.20638520e-02, 1.10499226e-02,
#         2.51952633e-03, 1.04380376e-03, 1.29575640e-03, 7.55857899e-04,
#         7.19864665e-05],
#        [1.85005219e-02, 2.56991686e-02, 1.96523054e-02, 1.41453407e-02,
#         4.49915416e-03, 1.33174963e-03, 2.51952633e-04, 1.79966166e-04,
#         0.00000000e+00],
#        [1.93643595e-02, 2.67069791e-02, 2.14879603e-02, 1.50811647e-02,
#         5.29100529e-03, 3.67130979e-03, 1.15178346e-03, 1.79966166e-04,
#         0.00000000e+00],
#        [2.57711550e-02, 2.82906814e-02, 3.38336393e-02, 2.10200482e-02,
#         1.02940647e-02, 5.97487672e-03, 5.39898499e-04, 1.07979700e-04,
#         0.00000000e+00],
#        [2.80747220e-02, 4.03124213e-02, 4.16801641e-02, 2.29636828e-02,
#         1.28135910e-02, 4.75110679e-03, 4.67912033e-04, 1.79966166e-04,
#         0.00000000e+00],
#        [2.12360076e-02, 3.31137746e-02, 4.32278732e-02, 3.26458626e-02,
#         2.04801497e-02, 1.05100241e-02, 4.85908649e-03, 1.69168196e-03,
#         0.00000000e+00],
#        [1.50451715e-02, 2.07680956e-02, 2.74988302e-02, 3.19979844e-02,
#         2.86506137e-02, 1.46852392e-02, 2.41154663e-03, 9.35824065e-04,
#         0.00000000e+00]])}, dtype=object)

# %%
plt.plot(ws)

# %%
plt.plot(wd)

# %%
plt.plot(w)

# %%
wr
# Out:
# array({'wd': array([ 22.5,  67.5, 112.5, 157.5, 202.5, 247.5, 292.5, 337.5]), 'ws': array([ 4.22222222,  6.66666667,  9.11111111, 11.55555556, 14.        ,
#        16.44444444, 18.88888889, 21.33333333, 23.77777778]), 'freq': array([[1.46852392e-02, 2.86146205e-02, 2.08400821e-02, 3.50574092e-02,
#         2.58791347e-02, 1.47932189e-02, 4.78710003e-03, 9.71817298e-04,
#         3.23939099e-04],
#        [2.59151280e-02, 2.53032430e-02, 2.20638520e-02, 1.10499226e-02,
#         2.51952633e-03, 1.04380376e-03, 1.29575640e-03, 7.55857899e-04,
#         7.19864665e-05],
#        [1.85005219e-02, 2.56991686e-02, 1.96523054e-02, 1.41453407e-02,
#         4.49915416e-03, 1.33174963e-03, 2.51952633e-04, 1.79966166e-04,
#         0.00000000e+00],
#        [1.93643595e-02, 2.67069791e-02, 2.14879603e-02, 1.50811647e-02,
#         5.29100529e-03, 3.67130979e-03, 1.15178346e-03, 1.79966166e-04,
#         0.00000000e+00],
#        [2.57711550e-02, 2.82906814e-02, 3.38336393e-02, 2.10200482e-02,
#         1.02940647e-02, 5.97487672e-03, 5.39898499e-04, 1.07979700e-04,
#         0.00000000e+00],
#        [2.80747220e-02, 4.03124213e-02, 4.16801641e-02, 2.29636828e-02,
#         1.28135910e-02, 4.75110679e-03, 4.67912033e-04, 1.79966166e-04,
#         0.00000000e+00],
#        [2.12360076e-02, 3.31137746e-02, 4.32278732e-02, 3.26458626e-02,
#         2.04801497e-02, 1.05100241e-02, 4.85908649e-03, 1.69168196e-03,
#         0.00000000e+00],
#        [1.50451715e-02, 2.07680956e-02, 2.74988302e-02, 3.19979844e-02,
#         2.86506137e-02, 1.46852392e-02, 2.41154663e-03, 9.35824065e-04,
#         0.00000000e+00]])}, dtype=object)

# %%
# Create a simple weather case, single wd, ws and weight
wd_ = np.asarray([270.0])
ws_ = np.asarray([13.5])
w_ = np.asarray([1.0])
wr = np.array(dict(
    wd=wd_, ws=ws_, freq=w_
))

wd_, ws_, w_, wr
# Out:
# (array([270.]),
#  array([13.5]),
#  array([1.]),
#  array({'wd': array([270.]), 'ws': array([13.5]), 'freq': array([1.])},
#        dtype=object))

# %%
np.savez(rf"./data/simple/weather_data.npz",
         wind_speed=ws_,
         wind_direction=wd_,
         weight=w_,
         windrose=wr)

# %%
# reload
b = np.load(rf"./data/simple/weather_data.npz", allow_pickle=True)
b
# Out:
# NpzFile './data/simple/weather_data.npz' with keys: wind_speed, wind_direction, weight, windrose

# %%
M = 3
type(M)
# Out:
# int

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 dtype.type(M)
#
# NameError: name 'dtype' is not defined
